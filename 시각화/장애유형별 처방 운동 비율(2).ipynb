# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family = 'Malgun Gothic')
plt.rcParams['font.size'] = 13

# %% [markdown]
# ### 1. 시각장애인 처방 운동 비율

# %%
plt.figure(figsize = (6, 6))
ratio = [18.4, 14.9, 12.9, 11.0, 7.5, 4.7, 4.7, 3.9, 3.1, 3.1, 2.4, 2.4, 2.0, 1.6, 1.6, 1.2, 1.2, .8, .8, .8, .8, .4]
labels = ['앉아서 위로 밀기', '실내 자전거타기', '앉아서 모으기', '트레드밀에서 걷기', '비스듬히 누워서 밀기', 
          '바벨들어올리기', '앉아서 다리 모으기', '누워서 밀기', '거꾸로 누워서 밀기', '서서 어깨 들어올리기', "몸통 들어올리기", "턱걸이", "바벨 끌어당기기", 
          "앉아서 다리 굽히기", "한발 앞으로 내밀고 앉았다 일어서기", "앉아서 뒤로 당기기", "앉아서 밀기", "매달려서 다리 들기", "앉아서 다리 밀기", 
          "앉아서 다리 벌리기", "허리 굽혀 덤벨 들기", "원판던지기"]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle = 90, counterclock=False, wedgeprops=wedgeprops)
plt.show()

# %%
plt.figure(figsize = (10, 10))
ratio = [18.4, 14.9, 12.9, 11.0, 7.5, 4.7, 4.7, 3.9, 3.1, 3.1, 2.4, 2.4, 2.0, 9.2]
# colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0', '#c0379a', '#1fda11', '#cc99ff', '#9966ff', '#ffd2ff', '#ffff33', '#b2ccff']
colors = ['#5a78af','#6482b9', '#3296ff', '#6e9fed', '#96a5ff', '#a0afff', '#aab9ff', '#b4c3ff', '#becdff', '#c8d7ff', '#d2e1ff', '#dcebff', '#c8ffff', '#e8f5ff', '#f4ffff']
labels = ['앉아서 위로 밀기', '실내 자전거타기', '앉아서 모으기', '트레드밀에서 걷기', '비스듬히 누워서 밀기', 
          '바벨들어올리기', '앉아서 다리 모으기', '누워서 밀기', '거꾸로 누워서 밀기', '서서 어깨 들어올리기', '몸통 들어올리기', 
          '턱걸이', '바벨 끌어당기기', '기타']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, colors = colors, autopct='%.1f%%', startangle = 90, counterclock=False, wedgeprops=wedgeprops, )
plt.title('시각장애인 처방 운동 비율', fontsize = 20)
plt.savefig('시각장애인 처방 운동 비율.png', dpi=300)
plt.show()

# %%
plt.figure(figsize = (10, 10))
ratio = [12.3,  8.7, 8.1, 7.8, 7.6, 4.3, 3.8, 3.7, 3.6, 3.5, 3.3, 3.3, 3.3, 3.2, 2.8, 2.7, 2.6, 2.6, 2.4, 2.1, 2.1, 6.2]
# colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0', '#c0379a', '#1fda11', '#cc99ff', '#9966ff', '#ffd2ff', '#ffff33', '#b2ccff']
colors = ['#3c5a91', '#466498', '#506ea5','#5a78af','#6482b9', '#288cff', '#3296ff', '#6e9fed', '#96a5ff', 
          '#a0afff', '#aab9ff', '#b4c3ff', '#becdff', '#c8d7ff', '#d2e1ff', 
          '#d2e1ff','#dcebff', '#c8ffff', '#dcebff', '#e8f5ff', '#ebfbff', '#f4ffff']
labels = ["앉아서 위로 밀기", "비스듬히 누워서 밀기", "앉아서 모으기", "서서 어깨 들어올리기", "바벨들어올리기", "앉아서 다리 모으기", "실내 자전거타기", 
          "매달려서 다리 들기", "거꾸로 누워서 밀기", "앉아서 당겨 내리기", "누워서 밀기", "원판던지기", "트레드밀에서 걷기", "한발 앞으로 내밀고 앉았다 일어서기", 
          "앉아서 다리 굽히기", "발 닿기", "바벨 끌어당기기", "턱걸이", "앉아서 다리 펴기", "앉아서 뒤로 당기기", "허리 굽혀 덤벨 들기", "기타"]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, colors = colors, autopct='%.1f%%', startangle = 90, counterclock=False, wedgeprops=wedgeprops)
plt.title('지적장애인 처방 운동 비율', fontsize = 20)
plt.savefig('pyvisual/지적장애인 처방 운동 비율.png', dpi=300)
plt.show()

# %%
plt.figure(figsize = (10, 10))
ratio = [14.1, 13.6, 10.2,  8.5,  6.2,  5.1,  4.0,  4.0,  3.4,  2.8,  2.8,  2.3,  2.3,  2.3,  2.3, 16.4]
# colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0', '#c0379a', '#1fda11', '#cc99ff', '#9966ff', '#ffd2ff', '#ffff33', '#b2ccff']
colors = ['#5a78af','#6482b9', '#3296ff', '#6e9fed', '#96a5ff', '#a0afff', '#aab9ff', '#b4c3ff', '#becdff', 
          '#c8d7ff', '#d2e1ff', '#dcebff', '#c8ffff', '#e8f5ff', '#ebfbff','#f4ffff']
labels = ["앉아서 모으기", "비스듬히 누워서 밀기", "서서 어깨 들어올리기", "앉아서 위로 밀기", "바벨 끌어당기기", "바벨들어올리기", 
          "거꾸로 누워서 밀기", "턱걸이", "원판던지기", "앉아서 다리 밀기", "앉아서 다리 펴기", "누워서 밀기", "매달려서 다리 들기", 
          "실내 자전거타기", "앉아서 다리 모으기", "기타"]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, colors = colors, autopct='%.1f%%', startangle = 90, counterclock=False, wedgeprops=wedgeprops)
plt.title('청각장애인 처방 운동 비율', fontsize = 20)
plt.savefig('청각장애인 처방 운동 비율.png', dpi=300)
plt.show()

# %%
plt.figure(figsize = (10, 10))
ratio = [12.2, 10.5, 10.5, 10.5,  8.8,  6.1,  6.1,  5.5,  3.3,  3.3,  2.8,  2.8,  2.2,  2.2,  2.2,  2.2,  9.1]
# colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0', '#c0379a', '#1fda11', '#cc99ff', '#9966ff', '#ffd2ff', '#ffff33', '#b2ccff']
colors = ['#5a78af','#6482b9', '#3296ff', '#6e9fed', '#96a5ff', '#a0afff', '#aab9ff', '#b4c3ff', '#becdff', '#c8d7ff', 
          '#d2e1ff', '#dcebff', '#c8ffff', '#e8f5ff', '#e8f5ff', '#ebfbff','#f4ffff']
labels = ["앉아서 모으기", "비스듬히 누워서 밀기", "앉아서 다리 굽히기", "앉아서 위로 밀기", "허리 굽혀 덤벨 들기", "바벨들어올리기", "앉아서 밀기", 
          "거꾸로 누워서 밀기", "실내 자전거타기", "앉아서 다리 밀기", "누워서 밀기",  "앉아서 다리 모으기", "매달려서 다리 들기", "앉아서 뒤로 당기기",
          "원판던지기", "트레드밀에서 걷기", "기타"]
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, labels=labels, colors = colors, autopct='%.1f%%', startangle = 90, counterclock=False, wedgeprops=wedgeprops)
plt.title('척수장애인 처방 운동 비율', fontsize = 20)
plt.savefig('척수장애인 처방 운동 비율.png', dpi = 300)
plt.show()
